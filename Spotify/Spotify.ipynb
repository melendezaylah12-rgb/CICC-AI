# %% [markdown]
# # What is the average/common tempo seen in songs from 2023?
# This is a census study because were refering to the data of all the songs of 2023 that are on Spotify.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("spotify-2023.csv", encoding = "latin-1")

# %%
df.head(10)
# Out:
#                             track_name              artist(s)_name  \
# 0  Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
# 1                                 LALA                 Myke Towers
# 2                              vampire              Olivia Rodrigo
# 3                         Cruel Summer                Taylor Swift
# 4                       WHERE SHE GOES                   Bad Bunny
# 5                             Sprinter           Dave, Central Cee
# 6                      Ella Baila Sola  Eslabon Armado, Peso Pluma
# 7                             Columbia                     Quevedo
# 8                             fukumean                       Gunna
# 9                      La Bebe - Remix       Peso Pluma, Yng Lvcas
#
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    str
#  1   artist(s)_name        953 non-null    str
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    str
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    str
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    str
#  14  bpm                   953 non-null    int64
# ...

# %%
Spotify=df["bpm"]

# %%
count = len(Spotify)
print("Spotify", count)
# Out:
# Spotify 953

# %%
df["bpm"].value_counts()
# Out:
# bpm
# 120    39
# 130    31
# 140    31
# 92     25
# 110    24
#        ..
# 189     1
# 200     1
# 196     1
# 188     1
# 165     1
# Name: count, Length: 124, dtype: int64

# %%
rel_freq_t = (200/(120+130+140+92+110+189+200+196+188+165) * 100)
rel_freq_t
# Out:
# 13.071895424836603

# %%
df.mode()
# Out:
#                                track_name artist(s)_name  artist_count  \
# 0                         About Damn Time   Taylor Swift           1.0
# 1                                Daylight            NaN           NaN
# 2                             Die For You            NaN           NaN
# 3                                 Flowers            NaN           NaN
# 4  Let It Snow! Let It Snow! Let It Snow!            NaN           NaN
# 5                                Miss You            NaN           NaN
# 6                                    Numb            NaN           NaN
# 7                                    SNAP            NaN           NaN
# 8                        SPIT IN MY FACE!            NaN           NaN
# 9                          Take My Breath            NaN           NaN
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0         2022.0             1.0           1.0                    86
# ...

# %%
sns.histplot(df, x="bpm")
mean = df["bpm"].mean()

plt.axvline(mean, linestyle="--", label=f"mean = {mean:.2f}")

# %%
df["bpm"].mean()
# Out:
# np.float64(122.54039874081847)

# %% [markdown]
# # Anaylsis
# The overall average of the BPM of the Songs of 2023 is 122.54. We can see that it's going to skew to the right because looking at the graph you can see that the quantitive distribution is going to be skewed and it would be more in the middle and skewed just to the right.

# %% [markdown]
# # Conclusion
# Based on the graph we can see that the most common average of BPM on Spotify 2023 is 122.54, and we can also see that the quantitive distrubution is to the right so it means that it might be in the same spot since it's more in the middle.
