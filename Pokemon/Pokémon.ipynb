# %% [markdown]
# # Question
# ### How does Mewtwo's attack compare to the other Pokémon's?
# This would be an census study because we have access to every Pokemon that's in the Pokedex

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("pokemon.csv")

# %%
df.head()
# Out:
#    national_number gen english_name japanese_name primary_type secondary_type  \
# 0                1   I    Bulbasaur   Fushigidane        grass         poison
# 1                2   I      Ivysaur    Fushigisou        grass         poison
# 2                3   I     Venusaur   Fushigibana        grass         poison
# 3                4   I   Charmander      Hitokage         fire            NaN
# 4                5   I   Charmeleon       Lizardo         fire            NaN
#
#    classification  percent_male  percent_female  height_m  ...  evochain_1  \
# 0    Seed Pokémon          87.5            12.5       0.7  ...      Level
# 1    Seed Pokémon          87.5            12.5       1.0  ...      Level
# 2    Seed Pokémon          87.5            12.5       2.0  ...      Level
# 3  Lizard Pokémon          87.5            12.5       0.6  ...      Level
# 4   Flame Pokémon          87.5            12.5       1.1  ...      Level
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 55 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   national_number     1025 non-null   int64
#  1   gen                 1025 non-null   str
#  2   english_name        1025 non-null   str
#  3   japanese_name       1025 non-null   str
#  4   primary_type        1025 non-null   str
#  5   secondary_type      526 non-null    str
#  6   classification      1025 non-null   str
#  7   percent_male        870 non-null    float64
#  8   percent_female      870 non-null    float64
#  9   height_m            1025 non-null   float64
#  10  weight_kg           1025 non-null   float64
#  11  capture_rate        1025 non-null   str
#  12  base_egg_steps      1025 non-null   int64
#  13  hp                  1025 non-null   int64
#  14  attack              1025 non-null   int64
#  15  defense             1025 non-null   int64
# ...

# %%
Pokemon=df["attack"]

# %%
count = len(Pokemon)
print("Pokemon",count)
# Out:
# Pokemon 1025

# %%
df["attack"].value_counts()
# Out:
# attack
# 80     48
# 100    48
# 60     46
# 65     46
# 55     43
#        ..
# 79      1
# 96      1
# 31      1
# 119     1
# 128     1
# Name: count, Length: 117, dtype: int64

# %%
relt_freq_t = (128/(80+100+60+65+55+79+96+31+119+128) * 100)
relt_freq_t
# Out:
# 15.744157441574416

# %%
df.mode()
# Out:
#       national_number  gen english_name japanese_name primary_type  \
# 0                   1    V    Abomasnow      Abagoura        water
# 1                   2  NaN         Abra         Absol          NaN
# 2                   3  NaN        Absol         Abuly          NaN
# 3                   4  NaN     Accelgor     Aburibbon          NaN
# 4                   5  NaN    Aegislash       Aceburn          NaN
# ...               ...  ...          ...           ...          ...
# 1020             1021  NaN      Zoroark      Zugaidos          NaN
# 1021             1022  NaN        Zorua        Zupika          NaN
# 1022             1023  NaN        Zubat       Zuruggu          NaN
# 1023             1024  NaN     Zweilous     Zuruzukin          NaN
# 1024             1025  NaN      Zygarde       Zygarde          NaN
#
#      secondary_type   classification  percent_male  percent_female  height_m  \
# 0            flying  Paradox Pokémon          50.0            50.0       0.6
# ...

# %%
df["attack"].mean()
# Out:
# np.float64(77.54146341463415)

# %%
df["attack"].median()
# Out:
# np.float64(75.0)

# %%
df["attack"].min()
# Out:
# np.int64(5)

# %%
df["attack"].max()
# Out:
# np.int64(181)

# %%
sns.histplot(df, x="attack")
mean = df["attack"].mean()

plt.axvline(mean, linestyle="--", label=f"mean = {mean:.2f}")
plt.axvline(134, linestyle="--", label=f"number = {134:.2f}")

# %%
two_std_attack = df["attack"].std()
two_std_attack
# Out:
# np.float64(29.81365445558379)

# %%
mean_attack = df["attack"].mean()
mean_attack
# Out:
# np.float64(77.54146341463415)

# %%
two_std_above = two_std_above + two_std_above + mean_attack
two_std_above
# Out:
# np.float64(662.0448617247741)

# %%
q3 = df["attack"].quantile(0.75)
q1 = df["attack"].quantile(0.25)

# %%
(q3-q1) * 1.5
# Out:
# np.float64(67.5)

# %%
sns.boxplot(df, x="attack")
# Out:
# <Axes: xlabel='attack'>

# %% [markdown]
# # Conclusion
# Based on the our graphs we can see that the IQR is 67.5 and in the boxplot graph we can see that we have one outlier in this data so we know that Mewtwo's attacks are in the middle between Q3 and the max than every other Pokemon that is in the graph which means some of the Pokemon that was in this data is more powerful than Mewtwo is known in the Pokedex, the Q1 is around 60, the Q3 is 100 but the max is around 175 but with the outlier it's going to be 180.
